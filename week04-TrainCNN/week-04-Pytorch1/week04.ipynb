# %% [markdown]
# ### github repo clone
#
# **runtime 유형을 T4 GPU로 변경해주세요!** 그렇지 않으면 모든 코드가 CPU에서 실행됩니다.
#
# colab에서 !, %를 이용해 shell command, IPython command를 사용할 수 있습니다.
# 본인 github에 과제를 올린 repo를 clone 해줍니다.

# %%
# !git clone [repo URL]
# Out:
# Cloning into 'week04-TrainCNN'...
# remote: Enumerating objects: 6880, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 6880 (delta 10), reused 14 (delta 7), pack-reused 6860
# Receiving objects: 100% (6880/6880), 100.72 MiB | 28.17 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# Updating files: 100% (6752/6752), done.

# %% [markdown]
# main.py 가 있는 디렉토리로 이동합니다.

# %%
# %cd /content/week04-TrainCNN/week-04-Pytorch1/
# Out:
# /content/week04-TrainCNN/week-04-Pytorch1

# %% [markdown]
# 사용가능한 GPU를 nvidia-smi를 이용해 모니터할 수 있습니다.

# %%
# !nvidia-smi
# Out:
# Tue Jan 30 13:04:45 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0              28W /  70W |      0MiB / 15360MiB |     12%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# 아래와 같이 main.py를 실행해줍니다.

# %%
# !python main.py -m 'CNN1' -e 100 -b 32 -lr 1e-4
# Out:
# (01/30 12:27:24 PM) INFO:training epoch 1
# 100% 152/152 [00:19<00:00,  7.72it/s]
# (01/30 12:27:44 PM) INFO:epoch 1 loss: 2.9810567890342914
# (01/30 12:27:44 PM) INFO:Validating epoch 1
# 100% 30/30 [00:02<00:00, 10.27it/s]
# (01/30 12:27:47 PM) INFO:epoch 1 accuracy = 0.07708333333333334
# (01/30 12:27:47 PM) INFO:training epoch 2
# 100% 152/152 [00:19<00:00,  7.80it/s]
# (01/30 12:28:06 PM) INFO:epoch 2 loss: 2.875262726294367
# (01/30 12:28:06 PM) INFO:Validating epoch 2
# 100% 30/30 [00:02<00:00, 10.51it/s]
# (01/30 12:28:09 PM) INFO:epoch 2 accuracy = 0.1134645061728395
# (01/30 12:28:09 PM) INFO:training epoch 3
# 100% 152/152 [00:18<00:00,  8.06it/s]
# (01/30 12:28:28 PM) INFO:epoch 3 loss: 2.767280489206314
# (01/30 12:28:28 PM) INFO:Validating epoch 3
# 100% 30/30 [00:03<00:00,  8.92it/s]
# (01/30 12:28:31 PM) INFO:epoch 3 accuracy = 0.12843364197530863
# (01/30 12:28:31 PM) INFO:training epoch 4
# 100% 152/152 [00:18<00:00,  8.05it/s]
# ...
